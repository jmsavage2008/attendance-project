# %%
#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

#Upload from csv
school_attendance_path = "school_attendance.csv"
school_score_path = "editme2.csv"

#Read data and results
attendance_df = pd.read_csv(school_attendance_path)
score_df = pd.read_csv(school_score_path)

score_df.head()
# Out:
#    FallOfYear                                RptngDistrictName  \
# 0      2022.0                      Barkhamsted School District
# 1      2022.0                           Berlin School District
# 2      2022.0  Stamford Charter School for Excellence District
# 3      2022.0       Capital Preparatory Harbor School District
# 4      2022.0                       Unified School District #1
#
#   ReportingDistrictCode SchoolName  SchoolCode SchoolOrgType SchoolLowGrade  \
# 0            ="0050011"   District  ="0000000"      District       District
# 1            ="0070011"   District  ="0000000"      District       District
# 2            ="2960013"   District  ="0000000"      District       District
# 3            ="2970013"   District  ="0000000"      District       District
# 4            ="3360015"   District  ="0000000"      District       District
#
#   SchoolHighGrade SchoolTitleIType     Category  ...  SupportCategory  \
# 0        District              NaN  DistrictTot  ...              NaN
# 1        District              NaN  DistrictTot  ...              NaN
# 2        District              NaN  DistrictTot  ...              NaN
# 3        District              NaN  DistrictTot  ...              NaN
# 4        District              NaN  DistrictTot  ...              NaN
#
#    Distinction  DistinctionCategory Perform ELA_ALL_YN Math_ALL_YN ELA_HN_YN  \
# 0          NaN                  NaN       .          .           .         .
# 1          NaN                  NaN       .          .           .         .
# 2          NaN                  NaN       .          .           .         .
# 3          NaN                  NaN       .          .           .         .
# 4          NaN                  NaN       .          .           .         .
#
#   Math_HN_YN Improve schoolyear
# 0          .       .    2022-23
# 1          .       .    2022-23
# 2          .       .    2022-23
# 3          .       .    2022-23
# 4          .       .    2022-23
#
# [5 rows x 120 columns]

# %%
#Filter data set to columns needed
score_df.columns
# Out:
# Index(['FallOfYear', 'RptngDistrictName', 'ReportingDistrictCode',
#        'SchoolName', 'SchoolCode', 'SchoolOrgType', 'SchoolLowGrade',
#        'SchoolHighGrade', 'SchoolTitleIType', 'Category',
#        ...
#        'SupportCategory', 'Distinction', 'DistinctionCategory', 'Perform',
#        'ELA_ALL_YN', 'Math_ALL_YN', 'ELA_HN_YN', 'Math_HN_YN', 'Improve',
#        'schoolyear'],
#       dtype='object', length=120)
